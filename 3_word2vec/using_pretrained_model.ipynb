# %%
# We will use the pre-trained weights of word2vec that was trained on Google New corpus containing 3 billion words. This model consists of 300-dimensional vectors for 3 million words and phrases.

# %%
# !pip install gensim wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 64.9 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=f265deeaccb100d7fee284e836fed67cca43cfd062bafb583f3b40e39d4db194
#   Stored in directory: /root/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# ...

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
# !wget -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"
# Above code of sir is not working as the model is not in the above URL now.
# We will download the model from huggingface

# %%
# from huggingface_hub import hf_hub_download

# # Download from the 'letha11/google-word2vec-bin' repo
# file_path = hf_hub_download(
#     repo_id="letha11/google-word2vec-bin",
#     filename="GoogleNews-vectors-negative300.bin.gz"
# )

# print("Downloaded to:", file_path)
# Out:
# GoogleNews-vectors-negative300.bin.gz:   0%|          | 0.00/1.65G [00:00<?, ?B/s]
# Downloaded to: /root/.cache/huggingface/hub/models--letha11--google-word2vec-bin/snapshots/4e22ba3d00eb68304e211ca00dc47b2acfc73cf9/GoogleNews-vectors-negative300.bin.gz

# %%
model = KeyedVectors.load_word2vec_format(
    file_path,
    binary = True,
    limit = 500_000 # load only first 500k vectors
)

# %%
model["cricket"].shape
# Out:
# (300,)

# %%
model.most_similar("man")
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824871301651001),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116),
#  ('guy', 0.5420035123825073)]

# %%
model.most_similar("cricket")
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
model.similarity("beautiful", "gorgeous")
# Out:
# np.float32(0.8353004)

# %%
model.similarity("man", "fan")
# Out:
# np.float32(0.2448795)

# %%
model.doesnt_match(["PHP", "java", "monkey"])    # Returns odd one out
# Out:
# 'monkey'

# %%
# We can apply any vector operation
vec = model["king"] - model["man"] + model["woman"]
model.most_similar([vec])
# Out:
# [('king', 0.8449392318725586),
#  ('queen', 0.7300517559051514),
#  ('monarch', 0.645466148853302),
#  ('princess', 0.6156251430511475),
#  ('crown_prince', 0.5818676352500916),
#  ('prince', 0.5777117609977722),
#  ('kings', 0.5613663792610168),
#  ('sultan', 0.5376775860786438),
#  ('queens', 0.5289887189865112),
#  ('ruler', 0.5247419476509094)]
